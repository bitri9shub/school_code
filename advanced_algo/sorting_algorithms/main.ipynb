# %% [markdown]
# ## Selection sort

# %%
import random

def selection_sort(list_to_sort):
    
    for i in range(len(list_to_sort)):
        minimum = list_to_sort[i]
        index_min = i
        for j in range(i+1, len(list_to_sort)):
            if minimum > list_to_sort[j]:
                minimum = list_to_sort[j]
                index_min = j
        if index_min != i:
            temp = list_to_sort[i]
            list_to_sort[i] = minimum
            list_to_sort[index_min] = temp
        else: 
            pass

    return list_to_sort

# Verification result on 10 random lists
for _ in range(10):
    print(selection_sort([random.randint(1,100000) for _ in range(10)]))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[21], line 24
#      22 # Verification result on 10 random lists
#      23 for _ in range(10):
# ---> 24     print(selection_sort([random.randint(1,100000) for _ in range(10)]))
#
# Cell In[21], line 5, in selection_sort(list_to_sort)
#       3 def selection_sort(list_to_sort):
#       4     minimum = list_to_sort[0]
# ----> 5     index_min = i
#       7     for i in range(len(list_to_sort)):
#       8         minimum = list_to_sort[i]
#
# UnboundLocalError: cannot access local variable 'i' where it is not associated with a value

# %% [markdown]
# ## Insertion sort
