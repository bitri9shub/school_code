# %% [markdown]
# ## Selection sort

# %%
import random

def selection_sort(list_to_sort):
    
    for i in range(len(list_to_sort)):
        minimum = list_to_sort[i]
        index_min = i
        for j in range(i+1, len(list_to_sort)):
            if minimum > list_to_sort[j]:
                minimum = list_to_sort[j]
                index_min = j
        if index_min != i:
            temp = list_to_sort[i]
            list_to_sort[i] = minimum
            list_to_sort[index_min] = temp
        else: 
            pass

    return list_to_sort

# Verification
for _ in range(10):
    print(selection_sort([random.randint(1,100000) for _ in range(10)]))
# Out:
# [2951, 4736, 6219, 26256, 33070, 58253, 70790, 72568, 84985, 88693]
# [14812, 22329, 25132, 27978, 28690, 50905, 51525, 62496, 93395, 94104]
# [9824, 14381, 20342, 21230, 24235, 24351, 36737, 41342, 69843, 76996]
# [1031, 12172, 16316, 17171, 27318, 30775, 32567, 59522, 79289, 90245]
# [8189, 16544, 19507, 29819, 38528, 60708, 65592, 71824, 77605, 92301]
# [7513, 13298, 15415, 39720, 41132, 45044, 58290, 76412, 91265, 96467]
# [18280, 20948, 23584, 40294, 42447, 45046, 52002, 61233, 69509, 98518]
# [15556, 21609, 39133, 44201, 45151, 46085, 70346, 86570, 93588, 96637]
# [8299, 10855, 16392, 20148, 46322, 54311, 61689, 63788, 67345, 85347]
# [699, 4332, 9041, 37284, 59912, 63938, 66896, 79777, 83699, 83929]

# %% [markdown]
# ## Insertion sort

# %%
import random 

def insertion_sort(list_to_sort, n):

    list_to_sort.append(random.randint(1,100000))
    list_to_sort.append(random.randint(1,100000))

    if list_to_sort[1] < list_to_sort[0]:
        list_to_sort[0] , list_to_sort[1] = list_to_sort[1], list_to_sort[0]

    list_of_random_number = [random.randint(1,10000) for _ in range(n-2)]

    for new_element in list_of_random_number:
        
        inserted = False

        for j in range(len(list_to_sort)-1):

            if new_element <= list_to_sort[j]:
                list_to_sort.insert(j, new_element)
                inserted = True
                break

            elif new_element >= list_to_sort[j] and new_element <= list_to_sort[j+1]:
                list_to_sort.insert(j+1, new_element)
                inserted = True
                break
            
        if not inserted:
            list_to_sort.append(new_element) 

    return list_to_sort

# Verification
for _ in range(10):
    print(insertion_sort([], 10))
# Out:
# [32, 552, 779, 1121, 2270, 3349, 7737, 9974, 44768, 73860]
# [467, 2488, 4550, 5741, 5855, 6238, 6360, 7466, 7552, 42386]
# [250, 2454, 3412, 3948, 4024, 5784, 7949, 8442, 56628, 79787]
# [472, 2118, 2411, 4448, 5639, 7430, 8632, 8762, 40640, 70477]
# [378, 1550, 1764, 2715, 4058, 4088, 5788, 7169, 62935, 74799]
# [1692, 2482, 2697, 3836, 4746, 5098, 6853, 8178, 29365, 33891]
# [2781, 4228, 4843, 4854, 5116, 5734, 6606, 9850, 9918, 23199]
# [820, 1200, 4907, 6153, 7009, 7242, 7337, 7901, 23891, 38858]
# [1260, 1263, 2277, 3403, 3891, 5467, 5677, 6108, 7561, 53175]
# [1182, 2370, 3317, 4247, 6358, 8452, 8594, 9926, 28797, 37700]

# %% [markdown]
# ## Bubble sort

# %%
import random

def bubble_sort(n):

    list_to_sort = [random.randint(1,10000) for _ in range(n)]

    for _ in range(len(list_to_sort)):
        for j in range(len(list_to_sort)-1):
            if list_to_sort[j] > list_to_sort[j+1]:
                list_to_sort[j], list_to_sort[j+1] = list_to_sort[j+1], list_to_sort[j]
    return list_to_sort

for _ in range(10):
    print(bubble_sort(20))
# Out:
# [250, 584, 876, 2137, 2740, 2887, 3037, 3082, 3271, 3937, 4302, 4856, 4878, 5389, 5602, 6955, 7575, 7740, 9123, 9269]
# [387, 634, 1164, 2415, 2727, 2733, 3921, 4128, 4287, 4466, 4718, 5527, 7259, 7362, 7366, 8193, 8314, 8337, 8588, 9886]
# [242, 2140, 2750, 3533, 3790, 4443, 4622, 4801, 5559, 5940, 6320, 6347, 6934, 7005, 7555, 7586, 8133, 8577, 8913, 9747]
# [750, 2742, 2744, 4033, 4086, 4904, 5967, 6335, 6576, 6796, 6873, 7374, 8179, 8611, 8652, 8821, 9120, 9300, 9606, 9720]
# [1289, 1762, 2040, 2543, 2944, 3113, 3650, 5008, 5104, 5553, 6157, 7081, 7455, 8092, 8378, 8504, 8722, 8725, 8886, 8915]
# [85, 183, 528, 735, 1139, 1274, 1571, 1931, 2290, 2812, 5248, 6249, 6571, 6933, 7013, 7188, 7377, 8127, 9900, 9920]
# [843, 1010, 1799, 1805, 2027, 2447, 2548, 2866, 3081, 3778, 4010, 4414, 5025, 5636, 6395, 7391, 7499, 9686, 9810, 9956]
# [231, 794, 1996, 2131, 2325, 2486, 2814, 5290, 6118, 6468, 6647, 6755, 7205, 7383, 7511, 7758, 7948, 8296, 8421, 8986]
# ...
